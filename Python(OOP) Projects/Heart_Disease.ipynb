# %% [markdown]
# # Mini Project: Hospital System

# %%
class Hospital:

    Reception = True

    def __init__(self , staff):

        self.staff = staff

    def hardworking(self):
        print(f'Hospital Duty = Hardworking.\nTotalStaff:{self.staff}')

    class System:

        def __init__(self , Environment):
            
            self.Environment = Environment

        def reliable(self):

            print("""Reliability = aik process ko similar method
            k through again & again repeat krna or jo claim aap
            ny kiya ha wo proof hojae""")

            print(f'Hospital Performance Is {self.Environment}')   

class Doctors(Hospital):

    def treatment(self):
        print('HeartPatient Surgeory')

    @classmethod
    def Dues(cls):
        print(f'PatientDues:{cls.Reception}')

d1:Doctors = Doctors(60)
d2 = d1.System('Best')

d1.treatment()
d1.hardworking()
d2.reliable()    
d1.Dues()
# Out:
# HeartPatient Surgeory
# Hospital Duty = Hardworking.
# TotalStaff:60
# Reliability = aik process ko similar method
#             k through again & again repeat krna or jo claim aap
#             ny kiya ha wo proof hojae
# Hospital Performance Is Best
# PatientDues:True
